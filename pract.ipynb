# %%
import pandas as pd

# %%
df=pd.read_csv('dataset_hate_speech.csv')
df=df.dropna(subset=['tweet'],how='any')
df.to_csv('dataset_hate_speech.csv',index=False)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Goyal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Vishal
# [nltk_data]     Goyal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
x=pd.read_csv("labeled_data.csv")

# %%
! pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Goyal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Vishal
# [nltk_data]     Goyal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
val=x.head(100)
val
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# ..         ...    ...          ...                 ...      ...    ...
# 95          96      3            0                   3        0      1
# 96          97      3            0                   3        0      1
# 97          98      3            0                   3        0      1
# 98          99      3            0                   3        0      1
# 99         100      3            1                   2        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# ...

# %%
import matplotlib.pyplot as mp

# %%
mp.pie(x['class'].value_counts().values,
       labels=x['class'].value_counts().index,
       autopct="%3f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x140556f61b0>,
# ...
#  [Text(-0.8349209376153136, 0.71617527738087, '1'),
#   Text(0.6921276491532292, -0.8549615881883962, '2'),
#   Text(1.08197654357046, -0.19830975559291156, '0')],
#  [Text(-0.4554114205174437, 0.39064106038956536, '77.432108%'),
#   Text(0.3775241722653977, -0.46634268446639787, '16.797805%'),
#   Text(0.5901690237657055, -0.10816895759613357, '5.770084%')])

# %%
from lemma import words_lemm

# %%
tr=x.head(100).drop(columns='Unnamed: 0',axis=1)
tr
# Out:
#     count  hate_speech  offensive_language  neither  class  \
# 0       3            0                   0        3      2
# 1       3            0                   3        0      1
# 2       3            0                   3        0      1
# 3       3            0                   2        1      1
# 4       6            0                   6        0      1
# ..    ...          ...                 ...      ...    ...
# 95      3            0                   3        0      1
# 96      3            0                   3        0      1
# 97      3            0                   3        0      1
# 98      3            0                   3        0      1
# 99      3            1                   2        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# 1   !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2   !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# ...

# %%
x["class"].value_counts()
# Out:
# class
# 1    19190
# 2     4163
# 0     1430
# Name: count, dtype: int64

# %%
import numpy as np

# %%
df_c1=x[x['class']==1].head(8000)

# %%
np.where(x['class']==1)
# Out:
# (array([    1,     2,     3, ..., 24778, 24780, 24781], dtype=int64),)

# %%
x.drop(index=np.where(x['class']==1)[0],axis=0,inplace=True)

# %%
X=pd.concat([df_c1,x], axis=0, ignore_index=True)

# %%
X['tweet']
# Out:
# 0        !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 1        !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 2        !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 3        !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 4        !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
#                                ...
# 13588    you know what they say, the early bird gets th...
# 13589                                   you're all niggers
# 13590    you're such a retard i hope you get type 2 dia...
# 13591    you've gone and broke the wrong heart baby, an...
# 13592    ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
# Name: tweet, Length: 13593, dtype: object

# %%
X["class"].value_counts()
# Out:
# class
# 1    8000
# 2    4163
# 0    1430
# Name: count, dtype: int64

# %%
import re
text="hoe 128514128514128514 blow shit &*876 faithful fucking tmadisonx somebody still meclaim"
text= re.findall(r'[^\d+!@#$%^&*()\{\}\\\|":\'/.,<>?]', text)
''.join(words for words in text)
# Out:
# 'hoe  blow shit  faithful fucking tmadisonx somebody still meclaim'

# %%
X['tweet']=X['tweet'].apply(lambda y: words_lemm(y))
# Out:
# hoe place boy rt dat coldtyga bad 1st cuffin dwn mleew17
# ever shit rt dawg 80sbaby4life fuck bitch urkindofbrand confused start cry
# like tranny rt cganderson look vivabase
# shit might rt faker ya hear true bitch 57361 shenikarobert tell
# hoe 128514128514128514 blow shit faithful fucking tmadisonx somebody still meclaim
# another go shit hate much bitch sit get brighterday
# tired I we skinny m 8220selfiequeenbri bitch 8221 big cause girl come
# that back might amp ya bitch s get
# fight hobby rhythmixx bitch mariam include
# walk like everyone lol bitch conversation smh keeks curve
# murda gang land bitch
# go hoe smoke loser ig yea
# thing like bad bitch
# get bitch
# miss nigga bitch
# plz whatever bitch
# love bitch
# b everyday bitch cut get
# amp bitch bottle black bad
# can not bitch nothing tell break
# like cancel nino bitch
# hoe change can not see will
# suck 128514128514128514 even do not bitch fuck bout videos ig dick kermit
# ...

# %%
df=pd.read_csv('dataset_hate_speech')
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  count  hate_speech  offensive_language  \
# 0                 0           1      3            0                   3
# 1                 1           2      3            0                   3
# 2                 2           3      3            0                   2
# 3                 3           4      6            0                   6
# 4                 4           5      3            1                   2
# ...             ...         ...    ...          ...                 ...
# 13588         13588       25280      3            0                   1
# 13589         13589       25289      3            3                   0
# 13590         13590       25290      3            2                   1
# 13591         13591       25292      3            0                   1
# 13592         13592       25296      3            0                   0
#
#        neither  class                                              tweet
# ...

# %%
import pandas as pd
import numpy as np
from lemma import words_lemm
x=pd.read_csv("labeled_data.csv")
df_c1=x[x['class']==1].head(8000)
x.drop(index=np.where(x['class']==1)[0],axis=0,inplace=True)
X=pd.concat([df_c1,x], axis=0, ignore_index=True)
X['tweet']=X['tweet'].apply(lambda y: words_lemm(y))
# Out:
#   boy dat coldtyga dwn bad cuffin dat hoe st place
#   Dawg ever fuck bitch start cry confuse shit
#   look like tranny
#   shit hear might true might faker bitch tell ya
#   shit blow meclaim faithful somebody still fuck hoe
#   sit hate another bitch get much shit go
#   cause tired big bitch come we skinny girl
#   amp might get ya bitch back amp
#   hobby include fight Mariam bitch
#   Keeks bitch curve everyone lol walk conversation like smh
#   Murda Gang bitch Gang Land
#   hoe smoke loser yea go IG
#   bad bitch thing like
#   bitch get
#   bitch nigga miss
#   bitch plz whatever
#   bitch love
#   bitch get cut everyday b
#   black bottle amp bad bitch
#   break bitch can not tell nothing
#   cancel bitch like Nino
#   can not see hoe will not change
#   fuck bitch not even suck dick Kermit video bout fuck IG
#   get ya bitch tip toe hardwood floor
#   pussy lip like Heaven door
#   hoe hit
#   meet pussy Ocean Dr give pussy pill
#   need trippy bitch fuck Hennessy
# ...

# %%
X.to_csv('dataset_hate_speech.csv')

# %%
import pandas as pd
X=pd.read_csv('dataset_hate_speech.csv')
X['tweet']=X['tweet'].str.replace(r'^\s+','',regex=True)
X['tweet']=X['tweet'].str.lower()
X.to_csv('create.csv')

# %%
X=pd.read_csv('dataset_hate_speech.csv')
X=X.sample(frac=1).reset_index(drop=True)
X.to_csv('dataset_hate_speech.csv',index=False)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
import pandas as pd
from sklearn.pipeline import Pipeline
# from keras.preprocessing.t
from keras.preprocessing.sequence import pad_sequences

df=pd.read_csv('sample_dataset.csv')
tweet_data=df['tweet']
class_data=df['class']

pipe=Pipeline([('select',SelectFromModel(LogisticRegression(class_weight='balanced',penalty="l1",C=0.01))),('model',LogisticRegression(class_weight='balanced',penalty='l2'))])
# vector conversion
x_train,x_val,y_train,y_val=train_test_split(tweet_data,class_data,test_size=0.2,random_state=22)

param_grid=[{}]
grid_search=GridSearchCV(pipe,param_grid,cv=StratifiedKFold(n_splits=5,random_state=42,shuffle=True).split(x_train,y_train),verbose=2)
model=grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 19
#      17 param_grid=[{}]
#      18 grid_search=GridSearchCV(pipe,param_grid,cv=StratifiedKFold(n_splits=5,random_state=42,shuffle=True).split(x_train,y_train),verbose=2)
# ---> 19 model=grid_search.fit(x_train,y_train)
#
# ...

# %%
import pandas as pd
import re
# Load your dataset
# Replace 'your_dataset.csv' with the actual path to your dataset
df = pd.read_csv('labeled_data.csv')

# Display basic information about the dataset
print("Original Dataset:")
print(df.info())

# Handle Missing Values
df = df.dropna()  # Remove rows with missing values

# Remove Duplicates
df = df.drop_duplicates()

# Remove Outliers (if applicable)
# You may use statistical methods or domain knowledge to identify and handle outliers

# Text Cleaning (if dealing with text data)
# Example: Convert text to lowercase
df['tweet'] = df['tweet'].str.lower()

# Tokenization, removing stopwords, and other text preprocessing steps can be applied

# Example: Remove special characters and punctuation
df['tweet'] = df['tweet'].apply(lambda x: re.sub(r'[^a-zA-Z\s]','',x))

# Save the cleaned dataset
# Replace 'cleaned_dataset.csv' with your desired file name
df.to_csv('cleaned_dataset.csv', index=False)

# Display information about the cleaned dataset
print("\nCleaned Dataset:")
print(df.info())
# Out:
# Original Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB
# None
#
# Cleaned Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
# ...

# %%
from typing import Counter
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
# Load your dataset
df = pd.read_csv('dataset_hate_speech.csv')

# Split the dataset into training and testing sets
train_data, test_data, train_labels, test_labels = train_test_split(
    df['tweet'], df['class'], test_size=0.2, random_state=42
)


# Create a pipeline with TF-IDF vectorization and SVC
model = make_pipeline(TfidfVectorizer(), SVC())

# Train the model
history=model.fit(train_data, train_labels)

# Make predictions on the test set
predictions = model.predict(test_data)

# Evaluate the model
accuracy = accuracy_score(test_labels, predictions)
classification_report_output = classification_report(test_labels, predictions)
confusion_mat = confusion_matrix(test_labels, predictions)

print(f"Accuracy: {accuracy}")
print("Classification Report:")
print(classification_report_output)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Accuracy: 0.8620816476645826
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.30      0.41       269
#            1       0.88      0.92      0.90      1593
#            2       0.86      0.94      0.90       857
#
#     accuracy                           0.86      2719
#    macro avg       0.79      0.72      0.73      2719
# weighted avg       0.85      0.86      0.85      2719
#
# Confusion Matrix:
# [[  81  148   40]
#  [  40 1459   94]
#  [   6   47  804]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
df['class'].value_counts()
# Out:
# class
# 1    2500
# 2    2000
# 0    2000
# Name: count, dtype: int64
